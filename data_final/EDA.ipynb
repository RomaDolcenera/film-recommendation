# %%
# Importo las librerias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# leo el dataset
dfm = pd.read_csv('../movies_clean.csv', low_memory=False)

# %%
dfc = pd.read_csv('../credits_clean.csv', low_memory=False)

# %%
dff = dfm[dfm['budget'] != 0]

# %%
# Relacion entre bugdet y revenue
plt.figure(figsize=(10, 6))
sns.scatterplot(data=dff, x='budget', y='revenue')
plt.title('Relación entre Budget y Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.show()

# %%
variables = dfm[['budget', 'revenue']]

# Matriz de correlación
correlation_matrix = variables.corr()

print(correlation_matrix)
# Out:
#            budget   revenue
# budget   1.000000  0.768761
# revenue  0.768761  1.000000

# %%
# Visualizacion de la matriz de correlación como un heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# El coeficiente de correlación entre "budget" y "revenue" es 0.77, lo que significaria que seria positiva.

# %%
# Clouds of words 
title_words = ' '.join(dfm['title'])
title_words = title_words.lower()
stopwords = ["to", "of", "the", "and", "&", ":", "in", "for", "on", "a", "by", "with", "an", "into", "from"]
wordcloud = WordCloud(stopwords=stopwords, background_color='white').generate(title_words)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.rcParams['font.family'] = 'arial'     
plt.title('Nube de palabras')
plt.show()

# %% [markdown]
# Al visualizar la Nube de palabras, se puede observar que las mas frecuentes son Love, Man, Day, girl, Night, day

# %% [markdown]
# Deteccion de Outliers en las columnas 'budget' y 'revenue'

# %%
columnas = ['budget','revenue']
dfm[columnas].boxplot()

plt.xlabel('Columnas')
plt.ylabel('Valores')
plt.title('Boxplot de budget y revenue')

plt.show()

# %%
# Budget
Q1 = dfm['budget'].quantile(0.25)
Q3 = dfm['budget'].quantile(0.75)
IQR = Q3 - Q1
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtro los registros que contienen outliers en la columna
outliers = dfm.loc[(dfm['budget'] < limite_inferior) | (dfm['budget'] > limite_superior)]

outliers
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 5      60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...     949
# 6      58000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...   11860
# ...         ...                                                ...     ...
# 45314   2000000                     [{'id': 35, 'name': 'Comedy'}]  293654
# 45320   2000000                     [{'id': 35, 'name': 'Comedy'}]  100152
# 45321    800000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   62757
# 45323   2000000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...   63281
# 45333   5000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   63898
#
#       original_language                                           overview  \
# 0                    en  Led by Woody, Andy's toys live happily in his ...
# 1                    en  When siblings Judy and Peter discover an encha...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 5                    en  Obsessive master thief, Neil McCauley leads a ...
# 6                    en  An ugly duckling having undergone a remarkable...
# ...                 ...                                                ...
# 45314                ru  Igor, a furniture store manager, tries to figu...
# 45320                ru  Somewhere deep, deep in Russia there is a town...
# 45321                en  The sea, August, interesting and simple people...
# 45323                en  У девушки Даши, приехавшей с подругой «покорят...
# 45333                ru  Failing to complete an important assignment wi...
#
#        popularity                               production_companies  \
# 0       21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1       17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 3        3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 5       17.924927  [{'name': 'Regency Enterprises', 'id': 508}, {...
# 6        6.677277  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# ...           ...                                                ...
# 45314    0.524370             [{'name': 'Enjoy Movies', 'id': 9340}]
# 45320    0.380933                                                 []
# 45321    0.903061                                                 []
# 45323    0.121844                  [{'name': 'Profit', 'id': 21163}]
# 45333    0.039793                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 5      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 6      [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   1995-12-15
# ...                                                  ...          ...
# 45314           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2014-09-18
# 45320                                                 []   2004-11-11
# 45321                                                 []   2006-11-23
# 45323           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2010-09-30
# 45333           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2007-09-06
#
#        release_year  ...                                   spoken_languages  \
# 0              1995  ...           [{'iso_639_1': 'en', 'name': 'English'}]
# 1              1995  ...  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 3              1995  ...           [{'iso_639_1': 'en', 'name': 'English'}]
# 5              1995  ...  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6              1995  ...  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# ...             ...  ...                                                ...
# 45314          2014  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45320          2004  ...                                                 []
# 45321          2006  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45323          2010  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45333          2007  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 3      Released  Friends are the people who let you be yourself...
# 5      Released                           A Los Angeles Crime Saga
# 6      Released  You are cordially invited to the most surprisi...
# ...         ...                                                ...
# 45314  Released                                                NaN
# 45320  Released                                                NaN
# 45321  Released                                                NaN
# 45323  Released                                                NaN
# 45333  Released                                                NaN
#
#                    title vote_average vote_count            franquicia  \
# 0              Toy Story          7.7     5415.0  Toy Story Collection
# 1                Jumanji          6.9     2413.0                   NaN
# 3      Waiting to Exhale          6.1       34.0                   NaN
# 5                   Heat          7.7     1886.0                   NaN
# 6                Sabrina          6.2      141.0                   NaN
# ...                  ...          ...        ...                   ...
# 45314    Corporate Event          3.5        4.0                   NaN
# 45320               Mars          5.0        2.0                   NaN
# 45321            Savages          5.8        6.0                   NaN
# 45323        Pro Lyuboff          4.0        3.0                   NaN
# 45333            Antidur          1.0        1.0                   NaN
#
#                                              productoras  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures, Teitler Film, Interscope Com...
# 3                 Twentieth Century Fox Film Corporation
# 5        Regency Enterprises, Forward Pass, Warner Bros.
# 6      Paramount Pictures, Scott Rudin Productions, M...
# ...                                                  ...
# 45314                                       Enjoy Movies
# 45320                                                NaN
# 45321                                                NaN
# 45323                                             Profit
# 45333                                                NaN
#
#                                   paises return
# 0               United States of America  12.45
# 1               United States of America   4.04
# 3               United States of America   5.09
# 5               United States of America   3.12
# 6      Germany, United States of America   0.00
# ...                                  ...    ...
# 45314                             Russia   0.00
# 45320                                NaN   0.00
# 45321                                NaN   1.66
# 45323                             Russia   0.63
# 45333                             Russia   0.28
#
# [8886 rows x 22 columns]

# %%
Q1 = dfm['revenue'].quantile(0.25)
Q3 = dfm['revenue'].quantile(0.75)
IQR = Q3 - Q1
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtro los registros que contienen outliers en la columna.
outliers = dfm.loc[(dfm['revenue'] < limite_inferior) | (dfm['revenue'] > limite_superior)]

outliers
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4             0                     [{'id': 35, 'name': 'Comedy'}]   11862
# 5      60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...     949
# ...         ...                                                ...     ...
# 45311    750000  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...  280422
# 45313         0  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...  240789
# 45321    800000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   62757
# 45323   2000000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...   63281
# 45333   5000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   63898
#
#       original_language                                           overview  \
# 0                    en  Led by Woody, Andy's toys live happily in his ...
# 1                    en  When siblings Judy and Peter discover an encha...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# 5                    en  Obsessive master thief, Neil McCauley leads a ...
# ...                 ...                                                ...
# 45311                ru                                                NaN
# 45313                ru  The film is based on real events that took pla...
# 45321                en  The sea, August, interesting and simple people...
# 45323                en  У девушки Даши, приехавшей с подругой «покорят...
# 45333                ru  Failing to complete an important assignment wi...
#
#        popularity                               production_companies  \
# 0       21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1       17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 3        3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4        8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# 5       17.924927  [{'name': 'Regency Enterprises', 'id': 508}, {...
# ...           ...                                                ...
# 45311    0.201582  [{'name': 'Кинокомпания «Lunapark»', 'id': 420...
# 45313    0.436028  [{'name': 'Central Partnership', 'id': 9342}, ...
# 45321    0.903061                                                 []
# 45323    0.121844                  [{'name': 'Profit', 'id': 21163}]
# 45333    0.039793                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# 5      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# ...                                                  ...          ...
# 45311           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2014-06-05
# 45313           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2009-10-09
# 45321                                                 []   2006-11-23
# 45323           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2010-09-30
# 45333           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2007-09-06
#
#        release_year  ...                                   spoken_languages  \
# 0              1995  ...           [{'iso_639_1': 'en', 'name': 'English'}]
# 1              1995  ...  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 3              1995  ...           [{'iso_639_1': 'en', 'name': 'English'}]
# 4              1995  ...           [{'iso_639_1': 'en', 'name': 'English'}]
# 5              1995  ...  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...             ...  ...                                                ...
# 45311          2014  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45313          2009  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45321          2006  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45323          2010  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45333          2007  ...           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# 5      Released                           A Los Angeles Crime Saga
# ...         ...                                                ...
# 45311  Released                                                NaN
# 45313  Released                                                NaN
# 45321  Released                                                NaN
# 45323  Released                                                NaN
# 45333  Released                                                NaN
#
#                              title vote_average vote_count  \
# 0                        Toy Story          7.7     5415.0
# 1                          Jumanji          6.9     2413.0
# 3                Waiting to Exhale          6.1       34.0
# 4      Father of the Bride Part II          5.7      173.0
# 5                             Heat          7.7     1886.0
# ...                            ...          ...        ...
# 45311                  All at Once          6.0        4.0
# 45313                  The Miracle          6.3        3.0
# 45321                      Savages          5.8        6.0
# 45323                  Pro Lyuboff          4.0        3.0
# 45333                      Antidur          1.0        1.0
#
#                            franquicia  \
# 0                Toy Story Collection
# 1                                 NaN
# 3                                 NaN
# 4      Father of the Bride Collection
# 5                                 NaN
# ...                               ...
# 45311                             NaN
# 45313                             NaN
# 45321                             NaN
# 45323                             NaN
# 45333                             NaN
#
#                                              productoras  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures, Teitler Film, Interscope Com...
# 3                 Twentieth Century Fox Film Corporation
# 4             Sandollar Productions, Touchstone Pictures
# 5        Regency Enterprises, Forward Pass, Warner Bros.
# ...                                                  ...
# 45311              Кинокомпания «Lunapark», Инвада фильм
# 45313  Central Partnership, Amkart Studios, Russian M...
# 45321                                                NaN
# 45323                                             Profit
# 45333                                                NaN
#
#                          paises return
# 0      United States of America  12.45
# 1      United States of America   4.04
# 3      United States of America   5.09
# 4      United States of America   0.00
# 5      United States of America   3.12
# ...                         ...    ...
# 45311                    Russia   0.00
# 45313                    Russia   0.00
# 45321                       NaN   1.66
# 45323                    Russia   0.63
# 45333                    Russia   0.28
#
# [7407 rows x 22 columns]
